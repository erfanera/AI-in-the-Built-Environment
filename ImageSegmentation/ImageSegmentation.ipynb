# %% [markdown]
# <a href="https://colab.research.google.com/github/erfanera/AI-in-the-Built-Environment/blob/main/ImageSegmentation/ImageSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Segmentaiton Practice:

# %%
from PIL import Image
import torchvision.transforms as transforms
import torch
from IPython.display import display

# %%
im1 = Image.open("/home/testDrive/Artboard 1.jpg")
mask = Image.open("/home/testDrive/mask.jpg")

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
tensorImage = transform(im1)
tensorMask = transform(mask)

# %%
resulted_Calc = tensorImage * tensorMask

# %%
to_pil_image = transforms.ToPILImage()
result = to_pil_image(resulted_Calc)

# %%
display(result)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
